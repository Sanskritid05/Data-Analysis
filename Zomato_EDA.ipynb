# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('zomato.csv' , encoding = 'latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## IN DATA ANALYSIS WHAT WE DO ?
# 1. Find missing values
# 2. Explore Numerical Variables
# 3. Explore Categorical Variables
# 4. Find Relationship between Features

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.shape
# Out:
# (9551, 21)

# %%
[non_null for non_null in df.columns if df[non_null].isnull().sum() > 0]
# Out:
# ['Cuisines']

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
dfc = pd.read_excel('Country-Code.xlsx')
dfc
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
dfc.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
final = pd.merge(df , dfc , on = 'Country Code' , how = 'left')
final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final.Country.values
# Out:
# array(['Phillipines', 'Phillipines', 'Phillipines', ..., 'Turkey',
#        'Turkey', 'Turkey'], shape=(9551,), dtype=object)

# %%
final.Country.value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
country_name = final.Country.value_counts().index
country_name
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'South Africa',
#        'UAE', 'New Zealand', 'Turkey', 'Australia', 'Phillipines', 'Indonesia',
#        'Qatar', 'Singapore', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
country_val = final.Country.value_counts().values
country_val
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4])

# %%
# top 3 countries that uses Zomato
top_3 = plt.pie(country_val[:3] , labels = country_name[:3] , autopct = '%1.2f%%')

# %% [markdown]
# ## TRANSACTION PRIVILEDGE
# 1. INDIA(Maj.)
# 2. Followed by USA , UK and others...
# 3. CANADA (Min.)

# %%
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
ratings = final.groupby(['Aggregate rating' , 'Rating color', 'Rating text']).size().reset_index().rename(columns = {0:"Rating Count"})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
total_ratings = ratings['Rating Count'].sum()
# green
total_good = ratings.loc[ratings['Rating text'].isin(['Excellent' , 'Very Good']) , 'Rating Count'].sum()
# average
total_average = ratings.loc[ratings['Rating text'].isin(['Good' , 'Average']) , 'Rating Count'].sum()
# poor
total_poor = ratings.loc[ratings['Rating text'] == 'Poor' , 'Rating Count'].sum()
# zero 
total_zeros = ratings.loc[ratings['Rating text'] == 'Not rated' , 'Rating Count'].sum()

print('Rating Nutshell\n')
print('Total Users :' , total_ratings + total_zeros)
print("Total Ratings : ",total_ratings)
print("Good Ratings : ",total_good)
print("Average Ratings : ",total_average)
print("Poor Ratings : ",total_poor)
print("Zero Ratings : ",total_zeros)
# Out:
# Rating Nutshell
#
# Total Users : 11699
# Total Ratings :  9551
# Good Ratings :  1380
# Average Ratings :  5837
# Poor Ratings :  186
# Zero Ratings :  2148

# %% [markdown]
# ### Rating Nutshell Keypoints
# 1. Total Users : 11699          (total_ratings + total_zeros)
# 2. Good Ratings :  1380         (4.0 to 4.9)
# 3. Average Ratings :  5837      (2.5 to 3.9)
# 4. Poor Ratings :  186          (1.8 to 2.4)
# 5. Zero Ratings :  2148         (0.0 to 0.0)

# %%
ratings.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
ratings['Rating color'].unique()
# Out:
# array(['White', 'Red', 'Orange', 'Yellow', 'Green', 'Dark Green'],
#       dtype=object)

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10 , 4)
palette = ['purple', 'red', 'orange', 'yellow', 'lightgreen', 'green']
sns.barplot(
    x='Aggregate rating',
    y='Rating Count',
    data=ratings,
    palette = palette
)
# Out:
# C:\Users\Sanskriti Dutta\AppData\Local\Temp\ipykernel_16932\358342354.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\Sanskriti Dutta\AppData\Local\Temp\ipykernel_16932\358342354.py:4: UserWarning:
# The palette list has fewer values (6) than needed (33) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
sns.countplot(x='Rating color' , data=ratings , palette=palette) #frequency of ratings
# Out:
# C:\Users\Sanskriti Dutta\AppData\Local\Temp\ipykernel_16932\1968162168.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating color' , data=ratings , palette=palette) #frequency of ratings
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Find the countries that has given 0 ratings
final.loc[final['Rating color'] == 'White'].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %% [markdown]
# ### Observations
# Max. Zero Ratings from INDIA

# %%
## Find out country - currency correspondence 
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final[['Country' , 'Currency']].groupby(['Country' , 'Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %%
## Countries with online delivery options 
final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final.loc[final['Has Online delivery'] == 'Yes'].groupby('Country').size().reset_index()
# Out:
#   Country     0
# 0   India  2423
# 1     UAE    28

# %%
final[['Has Online delivery','Country']].groupby(['Has Online delivery','Country']).size().reset_index().rename(columns={0:'Count'})
# Out:
#    Has Online delivery         Country  Count
# 0                   No       Australia     24
# 1                   No          Brazil     60
# 2                   No          Canada      4
# 3                   No           India   6229
# 4                   No       Indonesia     21
# 5                   No     New Zealand     40
# 6                   No     Phillipines     22
# 7                   No           Qatar     20
# 8                   No       Singapore     20
# 9                   No    South Africa     60
# 10                  No       Sri Lanka     20
# 11                  No          Turkey     34
# 12                  No             UAE     32
# 13                  No  United Kingdom     80
# 14                  No   United States    434
# 15                 Yes           India   2423
# 16                 Yes             UAE     28

# %% [markdown]
# ## Observations
# Online Delivery Available in Countries :
# 1. India
# 2. UAE

# %%
## Create a pie chart for cities distrib.

# %%
city_val = final.City.value_counts()
city_labels = final.City.value_counts().index

# %%
plt.pie(city_val[:5], labels=city_labels[:5] , autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2edaf3b64d0>,
# ...
#  [Text(-0.6145353730323401, 0.9123301350344637, 'New Delhi'),
#   Text(0.06236774886414425, -1.0982305149200777, 'Gurgaon'),
#   Text(0.878904221413572, -0.6614585169014024, 'Noida'),
#   Text(1.0922218482114119, -0.1305811406354216, 'Faridabad'),
#   Text(1.099946277419523, -0.010871374841004297, 'Ghaziabad')],
#  [Text(-0.33520111256309454, 0.4976346191097074, '68.87%'),
#   Text(0.03401877210771504, -0.5990348263200423, '14.07%'),
#   Text(0.479402302589221, -0.36079555467349217, '13.59%'),
#   Text(0.5957573717516791, -0.07122607671022996, '3.16%'),
#   Text(0.5999706967742853, -0.00592984082236598, '0.31%')])

# %%
## find the top 10 cuisines

# %%
cuisine_key = final.Cuisines.value_counts()[:10].keys()
cuisine_values = final.Cuisines.value_counts()[:10].values
top_10_cuisines = pd.DataFrame({'Cuisines':cuisine_key , 'Count': cuisine_values})
top_10_cuisines
# Out:
#                          Cuisines  Count
# 0                    North Indian    936
# 1           North Indian, Chinese    511
# 2                         Chinese    354
# 3                       Fast Food    354
# 4           North Indian, Mughlai    334
# 5                            Cafe    299
# 6                          Bakery    218
# 7  North Indian, Mughlai, Chinese    197
# 8                Bakery, Desserts    170
# 9                     Street Food    149

# %%
### figure of 2 columns (1 for table , 1 for chart)

fig , ax = plt.subplots(1, 2 , figsize=(14,5))

# Left side show table
ax[0].axis('tight')
ax[0].axis('off')

table = ax[0].table(cellText=top_10_cuisines.values,
                   colLabels=top_10_cuisines.columns, 
                   loc='center',
                   cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)

# Right side show graph
ax[1].barh(top_10_cuisines['Cuisines'] , top_10_cuisines['Count'] , color = 'orange')
ax[1].set_xlabel('Count')
ax[1].set_title('Top 10 Cuisines')
ax[1].invert_yaxis()

plt.tight_layout()
plt.show()
